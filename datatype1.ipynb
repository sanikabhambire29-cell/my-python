# %%
#Varrible

# %%
#Varrible is a name used to stored data

# %%
student_name="Sanika"

# %%
print(student_name)
# Out:
# Sanika

# %%
student_age=21

# %%
print(student_age)
# Out:
# 21

# %%
student_marks=88.5

# %%
print(student_marks)
# Out:
# 88.5

# %%
# Printing with labels

# %%
name="Sanika"

# %%
print("name:",name)
# Out:
# name: Sanika

# %%
age=21

# %%
print("age:",age)
# Out:
# age: 21

# %%
city="Mumbai"

# %%
print("city:",city)
# Out:
# city: Mumbai

# %%
#Changing the varrible values

# %%
Course="python"

# %%
print("Before changing:",Course)
# Out:
# Before changing: python

# %%
Course="Data science"

# %%
print("After changing:",Course)
# Out:
# After changing: Data science

# %%
#Multiple varribles

# %%
x,y,z=100,200,300

# %%
print("x=",x)
# Out:
# x= 100

# %%
print("y=",y)
# Out:
# y= 200

# %%
print("z=",z)
# Out:
# z= 300

# %%
#Same value to multiple varribles

# %%
maths = science = English = 90

# %%
print("maths",maths)
# Out:
# maths 90

# %%
print("science",science)
# Out:
# science 90

# %%
print("English",English)
# Out:
# English 90

# %%
#Invalid varribles name

# %%
2name="Sanika"
# Out:
#   Cell In[44], line 1
#     2name="Sanika"
#     ^
# SyntaxError: invalid decimal literal

# %%
student-name="aiti"
# Out:
#   Cell In[45], line 1
#     student-name="aiti"
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
full name="rahul"
# Out:
#   Cell In[46], line 1
#     full name="rahul"
#          ^
# SyntaxError: invalid syntax

# %%
class="python"
# Out:
#   Cell In[47], line 1
#     class="python"
#          ^
# SyntaxError: invalid syntax

# %%
#dynamic typing

# %%
# python automatically understands the data types

# %%
value=100

# %%
print(type(value))
# Out:
# <class 'int'>

# %%
value="python"

# %%
print(value)
# Out:
# python

# %%
print(type(value))
# Out:
# <class 'str'>

# %%
value=45.75

# %%
print(value)
# Out:
# 45.75

# %%
print(type(value))
# Out:
# <class 'float'>
