# %%
#File handling in Python is the process of creating, reading, writing, updating,
# and deleting files using functions like open()
# and file modes.

# %%
#create a sample file

# %%
with open("sample.txt","w")as f:
    f.write("Name: Rahul\n")
    f.write("Role: Data Scientist\n")
    f.write("Location: India\n")

# %%
#reading the file

# %%
with open("sample.txt", "r") as f:
    data = f.read()
    print(data)
# Out:
# Name: Rahul
# Role: Data Scientist
# Location: India

# %%
#reading the line by line

# %%
with open("sample.txt", "r") as f:
    for line in f:
        print(line.strip())
# Out:
# Name: Rahul
# Role: Data Scientist
# Location: India

# %%
with open("python.txt","w")as f:
  f.write("developer: Guido van Rossum\n")
  f.write("formation: March 6, 2001\n")
  f.write("Type: 501(c)(3)monoprofit organization\n")
  f.write(" purpose:Promote, protect, and advance the Python programming language, and to support and facilitate the growth of a diverse and international community of Python programmers[1]\n")
  f.write("Headquarters: wilminigton,dalaware\n")
  f.write("official language:english\t")
  f.write("chair:Jannis Leidel[2]" "\n")

# %%
#reading the line

# %%
with open("python.txt", "r") as f:
    data = f.read()
    print(data)
# Out:
# developer: Guido van Rossum
# formation: March 6, 2001
# Type: 501(c)(3)monoprofit organization
#  purpose:Promote, protect, and advance the Python programming language, and to support and facilitate the growth of a diverse and international community of Python programmers[1]
# Headquarters: wilminigton,dalaware
# official language:english	chair:Jannis Leidel[2]

# %%
#reading the line by line

# %%
with open("python.txt", "r") as f:
    for line in f:
        print(line.strip())
# Out:
# developer: Guido van Rossum
# formation: March 6, 2001
# Type: 501(c)(3)monoprofit organization
# purpose:Promote, protect, and advance the Python programming language, and to support and facilitate the growth of a diverse and international community of Python programmers[1]
# Headquarters: wilminigton,dalaware
# official language:english	chair:Jannis Leidel[2]

# %%
with open("python.txt", "w") as f:
    f.write("Developer:\tGuido van Rossum\n")
    f.write("Formation:\tMarch 6, 2001\n")
    f.write("Type:\t501(c)(3) nonprofit organization\n")
    f.write("Purpose:\t\"Promote, protect, and advance the Python programming language\"\n")
    f.write("Headquarters:\tWilmington, Delaware\n")
    f.write("Official Language:\tEnglish\n")
    f.write("Chair:\tJannis Leidel\n")
    f.write("Website:\thttps:\\\\www.python.org\n")

# %%
#reading the line

# %%
with open("python.txt", "r") as f:
    data = f.read()
    print(data)
# Out:
# Developer:	Guido van Rossum
# Formation:	March 6, 2001
# Type:	501(c)(3) nonprofit organization
# Purpose:	"Promote, protect, and advance the Python programming language"
# Headquarters:	Wilmington, Delaware
# Official Language:	English
# Chair:	Jannis Leidel
# Website:	https:\\www.python.org

# %%
#reading the line by line

# %%
with open("python.txt", "r") as f:
    for line in f:
        print(line.strip())
# Out:
# Developer:	Guido van Rossum
# Formation:	March 6, 2001
# Type:	501(c)(3) nonprofit organization
# Purpose:	"Promote, protect, and advance the Python programming language"
# Headquarters:	Wilmington, Delaware
# Official Language:	English
# Chair:	Jannis Leidel
# Website:	https:\\www.python.org

# %%
# Writing (Overwrite the File)

# %%
with open("sample.txt", "w") as f:
    f.write("This is new content\n")

# %%
# Appending Data

# %%
with open("sample.txt", "a") as f:
    f.write("Appended line 1\n")
    f.write("Appended line 2\n")

# %%
# Read Again After Append

# %%
with open("sample.txt", "r") as f:
    print(f.read())
# Out:
# Appended line 1
# Appended line 2

# %%
# Check if File Exists

# %%
import os

if os.path.exists("sample.txt"):
    print("File exists")
else:
    print("File not found")
# Out:
# File exists

# %%
#delete the file

# %%
import os
os.remove("sample.txt")
