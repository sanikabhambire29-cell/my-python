# %%
#function

# %%
# a function is a block of resuablecode that performs a specific task

# %%
# built-in function
# functions already provided by python

# %%
print("hello")
# Out:
# hello

# %%
len("python")
# Out:
# 6

# %%
type(10)
# Out:
# int

# %%
#user - defined functions

# %%
# simple functions

# %%
def greet():
  print("hello world")
greet()
# Out:
# hello world

# %%
def A():
  print("my python")

A()
# Out:
# my python

# %%
#function with parameter

# %%
def greet(name):
  print("hello",name)
greet("sanika")
# Out:
# hello sanika

# %%
def greet(name):
  print(name)
greet(3)
# Out:
# 3

# %%
def greet(number):
  print(number)
greet(10)
# Out:
# 10

# %%
#function with return value

# %%
def greet(name,age):
  print(name,age)
greet("sanika","18")
# Out:
# sanika 18

# %%
#function with return value

# %%
def add(a,b):
  return a + b
result = add (10,20)
print(result)
# Out:
# 30

# %%
def mul(a,b):
  return a * b
result =  mul (10,5)
print (result)
# Out:
# 50

# %%
#default parameter

# %%
def A(a,b):
  add=a+b
  mul=a*b
  return add + mul
result = A(10,5)
print(result)
# Out:
# 65

# %%
#default parameter

# %%
def greet (name="user"):
  print("hello",name)

greet()
greet("sanika")
# Out:
# hello user
# hello sanika

# %%
def greet (name="user"):
  print("hello",name)

greet()
# Out:
# hello user

# %%
def greet (name="Aditi"):
  print("hello",name)

greet()
greet("sanika")
# Out:
# hello Aditi
# hello sanika

# %%
def greet():
  print("i like java programming")
greet()
# Out:
# i like java programming

# %%
def greet(sub="python"):
  print(f"i like {sub} programming")
greet()
greet("java")
# Out:
# i like python programming
# i like java programming

# %%
#types of argument

# %%
#positional argument

# %%
def show (name , age):
    print(name, age)
show("aditi",18)
# Out:
# aditi 18

# %%
def show(name,age):
  print(f"i am {name} and i am  {age} year old")

show("sanika",18)
# Out:
# i am sanika and i am  18 year old

# %%
def show(age,name):
  print(f"i am {age}  year old and my name is {name} ")

show(18,"sanika")
# Out:
# i am 18  year old and my name is sanika

# %%
def show(age,name):
  print(f"i am {name} and i am  {age} year old")

show("sanika",18)
# Out:
# i am 18 and i am  sanika year old

# %%
#keyword arguments

# %%
def show(name="sanika",age=18):
  print(f"i am {name} and i am  {age} year old")

show("sanika",18)
# Out:
# i am sanika and i am  18 year old

# %%
def show(name="sanika",age=18,marks=99):
  print(f"i am {name} and  my prcentage is  {marks}  and i am  {age} year old")

show("sanika",18,99)
# Out:
# i am sanika and  my prcentage is  99  and i am  18 year old

# %%
# **kwargs(key value)

# %%
def info(**data):
    print(data)
info(name="sanika",age=18)
# Out:
# {'name': 'sanika', 'age': 18}

# %%
def info(**data):
    print(data)
info(name="sanika",age=18 , marks=99.9, )
# Out:
# {'name': 'sanika', 'age': 18, 'marks': 99.9}

# %%
#varrible-length arguments

# %%
#* args(multiple values)

# %%
def add(*nums):
  print(sum(nums))
add(10, 20, 30)
# Out:
# 60

# %%
def mul(*nums):
    result = 1
    for num in nums:
        result *= num
    print(result)

mul(10, 20, 30)
# Out:
# 6000

# %%
#lambda function (anonymous function)

# %%
add = lambda a,b: a+b
print(add(10,20))
# Out:
# 30
