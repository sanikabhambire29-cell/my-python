# %%
#NumPy

# %%
# %pip install numpy

# %%
import numpy as np

# %%
# creating Arrays

# %%
sample_array = np.array([1,2,3,4])

# %%
sample_array
# Out:
# array([1, 2, 3, 4])

# %%
#2D Array(Matrix)

# %%
sample_array2 = np.array([[1,2],[3,4]])

# %%
sample_array2
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
#3D(Tensor)

# %%
sample_array3 = np.array([[[1,2],[3,4]],[[6,7],[6,0]]])

# %%
sample_array3
# Out:
# array([[[1, 2],
#         [3, 4]],
#
#        [[6, 7],
#         [6, 0]]])

# %%
# Dimensions
#0-D(Scalar) - Single Number
# 1-D(Vector) - List
# 2-D(Matrix) - A table with rows and columns
# 3-D(Tensor) - A stack of Tables

# %%
sample_array = np.array([[[34,56],[67,98]],[[43,95],[89,43]]])

# %%
sample_array
# Out:
# array([[[34, 56],
#         [67, 98]],
#
#        [[43, 95],
#         [89, 43]]])

# %%
# Array Properties

# %%
sample_array2 = np.array([[34,45],[67,98]])

# %%
sample_array2
# Out:
# array([[34, 45],
#        [67, 98]])

# %%
#shape

# %%
sample_array2.shape
# Out:
# (2, 2)

# %%
sample_array2.ndim
# Out:
# 2

# %%
sample_array2.size
# Out:
# 4

# %%
sample_array2.dtype
# Out:
# dtype('int64')

# %%
sample3= np.array([[[34,56],[67,98]],[[56,90],[23,78]]])

# %%
sample3
# Out:
# array([[[34, 56],
#         [67, 98]],
#
#        [[56, 90],
#         [23, 78]]])

# %%
sample3.shape
# Out:
# (2, 2, 2)

# %%
sample3.ndim
# Out:
# 3

# %%
sample3.dtype
# Out:
# dtype('int64')

# %%
sample3.size
# Out:
# 8

# %%
sample2_array = np.array([[0,0,0],[0,0,0]])

# %%
sample2_array
# Out:
# array([[0, 0, 0],
#        [0, 0, 0]])

# %%
sample2_array = np.array([[1,1,1],[1,1,1]])

# %%
sample2_array
# Out:
# array([[1, 1, 1],
#        [1, 1, 1]])

# %%
# Specials arrays

# %%
np.zeros((2,3))
# Out:
# array([[0., 0., 0.],
#        [0., 0., 0.]])

# %%
np.ones((2,3))
# Out:
# array([[1., 1., 1.],
#        [1., 1., 1.]])

# %%
np.arange(0,10,2)
# Out:
# array([0, 2, 4, 6, 8])

# %%
np.arange(0,100,3)
# Out:
# array([ 0,  3,  6,  9, 12, 15, 18, 21, 24, 27, 30, 33, 36, 39, 42, 45, 48,
#        51, 54, 57, 60, 63, 66, 69, 72, 75, 78, 81, 84, 87, 90, 93, 96, 99])

# %%
# Array Operations

# %%
Array_A=np.array([1,2,3,4,5])
Array_B=np.array([6,7,8,9,0])

# %%
Array_A
# Out:
# array([1, 2, 3, 4, 5])

# %%
Array_B
# Out:
# array([6, 7, 8, 9, 0])

# %%
Array_A + Array_B
# Out:
# array([ 7,  9, 11, 13,  5])

# %%
Array_A - Array_B
# Out:
# array([-5, -5, -5, -5,  5])

# %%
Array_A * Array_B
# Out:
# array([ 6, 14, 24, 36,  0])

# %%
Array_A / Array_B
# Out:
# /tmp/ipykernel_2869/4100675645.py:1: RuntimeWarning: divide by zero encountered in divide
#   Array_A / Array_B
# array([0.16666667, 0.28571429, 0.375     , 0.44444444,        inf])

# %%
#mathematical function

# %%
A1=np.array([1,4,9])

# %%
A1
# Out:
# array([1, 4, 9])

# %%
np.sqrt(A1)
# Out:
# array([1., 2., 3.])

# %%
np.sqrt(27)
# Out:
# np.float64(5.196152422706632)

# %%
np.log(0)
# Out:
# /tmp/ipykernel_2869/2933082444.py:1: RuntimeWarning: divide by zero encountered in log
#   np.log(0)
# np.float64(-inf)

# %%
np.log(1)
# Out:
# np.float64(0.0)

# %%
np.log(A1)
# Out:
# array([0.        , 1.38629436, 2.19722458])

# %%
np.exp(A1)
# Out:
# array([2.71828183e+00, 5.45981500e+01, 8.10308393e+03])

# %%
# statistical Function

# %%
A2 = np.array([1,2,3,4,5])

# %%
A2
# Out:
# array([1, 2, 3, 4, 5])

# %%
np.mean(A2)
# Out:
# np.float64(3.0)

# %%
np.median(A2)
# Out:
# np.float64(3.0)

# %%
np.std(A2)
# Out:
# np.float64(1.4142135623730951)

# %%
np.min(A2)
# Out:
# np.int64(1)

# %%
np.max(A2)
# Out:
# np.int64(5)

# %%
s1 = np.array([68,67,58,1003])

# %%
s1
# Out:
# array([  68,   67,   58, 1003])

# %%
np.mean(s1)
# Out:
# np.float64(299.0)

# %%
np.median(s1)
# Out:
# np.float64(67.5)

# %%
np.std(s1)
# Out:
# np.float64(406.47324635208156)

# %%
np.min(s1)
# Out:
# np.int64(58)

# %%
np.max(s1)
# Out:
# np.int64(1003)

# %%
s2=np.array([[1,2],[3,4]])

# %%
s2
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
#Flattening

# %%
s2.flatten()
# Out:
# array([1, 2, 3, 4])

# %%
s3=np.array([[[34,56],[67,98]],[[23,67],[56,54]]])

# %%
s3
# Out:
# array([[[34, 56],
#         [67, 98]],
#
#        [[23, 67],
#         [56, 54]]])

# %%
s3.flatten()
# Out:
# array([34, 56, 67, 98, 23, 67, 56, 54])

# %%
a1=np.array([1,2])
a2=np.array([3,4])

# %%
a1
# Out:
# array([1, 2])

# %%
a2
# Out:
# array([3, 4])

# %%
np.concatenate((a1,a2))
# Out:
# array([1, 2, 3, 4])

# %%
A=np.array([1,2,3,4])

# %%
A
# Out:
# array([0, 1, 2, 3, 4, 5])

# %%
np.array_split(A,2)
# Out:
# [array([1, 2]), array([3, 4])]

# %%
# Random Module

# %%
np.random.rand(3)
# Out:
# array([0.01624499, 0.62967197, 0.65161899])

# %%
np.random.rand(10)
# Out:
# array([0.77895059, 0.38126651, 0.26546184, 0.00631904, 0.78969081,
#        0.65689534, 0.84746154, 0.84120795, 0.41160539, 0.34319213])

# %%
np.random.randint(1,100,10)
# Out:
# array([50, 24, 55, 22, 31,  1, 75, 68, 86,  1])

# %%
A=np.array([[74,89],[58,99]])

# %%
A
# Out:
# array([[74, 89],
#        [58, 99]])

# %%
np.sum(A,axis=0)
# Out:
# array([132, 188])

# %%
np.sum(A,axis=1)
# Out:
# array([163, 157])

# %%
a1=np.array([1,np.nan,3])

# %%
a1
# Out:
# array([ 1., nan,  3.])

# %%
np.isnan(a1)
# Out:
# array([False,  True, False])

# %%
a1=np.array([[23,np.nan],[34,np.nan]])

# %%
a1
# Out:
# array([[23., nan],
#        [34., nan]])

# %%
np.isnan(a1)
# Out:
# array([[False,  True],
#        [False,  True]])

# %%
A=np.array([0,1,2,3,4,5])

# %%
A
# Out:
# array([0, 1, 2, 3, 4, 5])

# %%
reshaped= A.reshape(2,3)

# %%
reshaped
# Out:
# array([[0, 1, 2],
#        [3, 4, 5]])
